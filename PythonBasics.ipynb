# %%
n = {1: 2, 2:3, 3:4}
print(n.get(100, 10))
print(n)
n.items()
# Out:
# 10
# {1: 2, 2: 3, 3: 4}
# dict_items([(1, 2), (2, 3), (3, 4)])

# %%
for i in n.items():
    print(i)
# Out:
# (1, 2)
# (2, 3)
# (3, 4)

# %%
for i in n.items():
    print(i[0])
# Out:
# 1
# 2
# 3

# %%
for i in n.items():
    print(i[1])
# Out:
# 2
# 3
# 4

# %%
n = {3:1, 2:2, 1:1}
n.pop(3)
# Out:
# 1

# %%
print(n)
# Out:
# {2: 2, 1: 1}

# %%
print("Helo world")
# Out:
# Helo world
