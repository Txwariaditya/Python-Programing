# %%
n = {1: 2, 2:3, 3:4}
print(n.get(100, 10))
print(n)
n.items()
# Out:
# 10
# {1: 2, 2: 3, 3: 4}
# dict_items([(1, 2), (2, 3), (3, 4)])

# %%
for i in n.items():
    print(i)
# Out:
# (1, 2)
# (2, 3)
# (3, 4)

# %%
for i in n.items():
    print(i[0])
# Out:
# 1
# 2
# 3

# %%
for i in n.items():
    print(i[1])
# Out:
# 2
# 3
# 4

# %%
n = {3:1, 2:2, 1:1}
n.pop(3)
# Out:
# 1

# %%
set1 = {1,2,3,4,5}
set1.add(6)
set1.remove(3)

list1 = [10,20,30,40,50]
set2 = set(list1)


print(set2)
# Out:
# {40, 10, 50, 20, 30}

# %%
dict1 =dict()
dict1 = {"name":"aditya", "age": 20, "city": "jaipur"}


print(dict1["age"])

# print(dir(dict1))
# Out:
# 20

# %%
max([1,23,43,3],[2,4,3,2,32])
# Out:
# [2, 4, 3, 2, 32]
